# %%
! pip install update
! pip install upgrade
! pip install --upgrade pip
! pip install -U backtrader yfinance tensorforce
# Out:
# Collecting update
#   Downloading update-0.0.1-py2.py3-none-any.whl (2.9 kB)
# Collecting style==1.1.0
#   Downloading style-1.1.0-py2.py3-none-any.whl (6.4 kB)
# Installing collected packages: style, update
# Successfully installed style-1.1.0 update-0.0.1
# Requirement already up-to-date: pip in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (20.1)
# Requirement already up-to-date: backtrader in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (1.9.74.123)
# Processing /home/nbuser/.cache/pip/wheels/eb/b6/66/e3233eafc61d2fc483cba27003e838128b2b620f52f48619ea/yfinance-0.1.54-py2.py3-none-any.whl
# Collecting tensorforce
#   Using cached Tensorforce-0.5.4-py3-none-any.whl (344 kB)
# Collecting pandas>=0.24
#   Using cached pandas-0.25.3-cp35-cp35m-manylinux1_x86_64.whl (10.3 MB)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from yfinance) (1.17.3)
# Collecting requests>=2.20
#   Using cached requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Processing /home/nbuser/.cache/pip/wheels/59/7e/17/1d79ecdcbfbfc67d4d7a39077ca7ceb1b94b9b58f4d257897b/multitasking-0.0.9-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: tqdm in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from tensorforce) (4.37.0)
# Collecting msgpack
#   Using cached msgpack-1.0.0-cp35-cp35m-manylinux1_x86_64.whl (270 kB)
# Requirement already satisfied, skipping upgrade: gym in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from tensorforce) (0.12.5)
# Requirement already satisfied, skipping upgrade: h5py in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from tensorforce) (2.7.1)
# Collecting msgpack-numpy
#   Using cached msgpack_numpy-0.4.5-py2.py3-none-any.whl (6.1 kB)
# Requirement already satisfied, skipping upgrade: pytest in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from tensorforce) (2.9.2)
# Requirement already satisfied, skipping upgrade: matplotlib in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from tensorforce) (2.1.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Collecting pytz>=2017.2
#   Using cached pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Collecting chardet<4,>=3.0.2
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from requests>=2.20->yfinance) (1.25.6)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from requests>=2.20->yfinance) (2.8)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from requests>=2.20->yfinance) (2019.9.11)
# Requirement already satisfied, skipping upgrade: scipy in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from gym->tensorforce) (1.1.0)
# Requirement already satisfied, skipping upgrade: six in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from gym->tensorforce) (1.11.0)
# Requirement already satisfied, skipping upgrade: pyglet>=1.2.0 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from gym->tensorforce) (1.4.6)
# Requirement already satisfied, skipping upgrade: py>=1.4.29 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from pytest->tensorforce) (1.4.31)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from matplotlib->tensorforce) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from matplotlib->tensorforce) (2.1.4)
# Requirement already satisfied, skipping upgrade: future in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from pyglet>=1.2.0->gym->tensorforce) (0.18.2)
# ERROR: azure-storage-queue 12.0.0 has requirement cryptography>=2.1.4, but you'll have cryptography 2.0.3 which is incompatible.
# ERROR: azure-storage-blob 12.0.0 has requirement cryptography>=2.1.4, but you'll have cryptography 2.0.3 which is incompatible.
# Installing collected packages: pytz, pandas, chardet, requests, multitasking, yfinance, msgpack, msgpack-numpy, tensorforce
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2016.6.1
# ERROR: Cannot uninstall 'pytz'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
# Strategy

from datetime import datetime
import backtrader
import random

# Integrate Model
import sys
import warnings
import numpy
import pandas
warnings.filterwarnings('ignore')
# Build Instance and draw single plot
#為了將GUI圖形顯示在 Jupyter notebook 
# %matplotlib inline
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot

# %%
# NO Freelaunch
# NO Freelaunch
# NO Freelaunch
# NO Freelaunch
# NO Freelaunch
# NO Freelaunch

# %%
import tensorforce
from tensorforce.agents import Agent

Network_Config = [
    dict(type='lstm', size=1500, activation='relu'),
    dict(type='lstm', size=128, activation='relu'),
    dict(type='lstm', size=64, activation='relu'),
    dict(type='lstm', size=128, activation='relu'),
    dict(type='lstm', size=64, activation='relu'),
    dict(type='lstm', size=128, activation='relu'),
    dict(type='lstm', size=64, activation='relu'),
    dict(type='flatten')]


States_Config = dict(type="float", shape=(1500,))
Actions_Config = dict(type="float", shape=1)

Agent_A2C = Agent.create(
    agent="a2c", 
    network = Network_Config ,
    states = States_Config,
    actions = Actions_Config,
    learning_rate=1e-1)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-8b7946c8cd0d> in <module>()
# ----> 1 import tensorforce
#       2 from tensorforce.agents import Agent
#       3
#       4 Network_Config = [
#       5     dict(type='lstm', size=1500, activation='relu'),
#
# ImportError: No module named 'tensorforce'

# %%
def Function_For_Build_Customize_Object(Parameter1, Parameter2):
    
    class Customize_Object(backtrader.Strategy):
        
        
        def __init__(self):
    
            self.data_open = self.datas[0].open
            self.data_high = self.datas[0].high
            self.data_low = self.datas[0].low
            self.data_close = self.datas[0].close
            self.data_volume = self.datas[0].volume
        
            self.FeatureData_PeriodRange_Start = 0
            self.FeatureData_PeriodRange_End = -300
            
            self.Position_Value = 10000
            self.Observation_State = None
            self.Step_Reward = 0        
            self.Empirical_Reward = 0                
    
    
            
        def next(self):
            
            def Function_Make_FeatureDataSet(From_Period, To_Period) :
                
                Im_Feature_DataSet = []
                
                for TimeSequence in range( From_Period, To_Period, -1) :
                    
                    Im_Feature_DataSet.append(self.data_open[TimeSequence])
                    Im_Feature_DataSet.append(self.data_high[TimeSequence])
                    Im_Feature_DataSet.append(self.data_low[TimeSequence])
                    Im_Feature_DataSet.append(self.data_close[TimeSequence])
                    Im_Feature_DataSet.append(self.data_volume[TimeSequence])
    
                return Im_Feature_DataSet            
            
################################################################################################            
#                                      Space for Customize Strategy   
################################################################################################           


            Im_Current_Feature_DataSet = numpy.reshape(
                Function_Make_FeatureDataSet(0, self.FeatureData_PeriodRange_End - self.FeatureData_PeriodRange_Start),
                (1,1, 5*( self.FeatureData_PeriodRange_Start - self.FeatureData_PeriodRange_End) ))
            
            self.Observation_State = Im_Current_Feature_DataSet

            actions = Agent_A2C.act(states=self.Observation_State)

            if actions >= 0.1:
                self.buy(actions)
                print("Buying : {}".format(actions))                
            if actions <= -0.1:
                self.sell(actions)
                print("Selling : {}".format(actions))

            Im_Current_PositionDifference = self.broker.getvalue() - self.Position_Value
            self.Step_Reward = Im_Current_PositionDifference                
            
            reward = self.Step_Reward
            Agent_A2C.observe(terminal=False, reward=reward)  
     
                
            self.Empirical_Reward = self.Empirical_Reward + self.Step_Reward
            self.Position_Value = self.broker.getvalue()                

            print("============================================{}============================================".format(self.data.datetime.datetime()))
                
        
            Pandas_Data = pandas.DataFrame({"Open Price": self.data_open[0],
                                    "High Price": self.data_high[0],
                                    "Low Price": self.data_low[0],
                                    "Close Price": self.data_close[0],
                                    "Volumns": self.data_volume[0],
                                    "Position": self.Position_Value,
                                    "Action": Action_Select,
                                    "Current Reward": Im_Current_PositionDifference,
                                    "Total Reward": self.Empirical_Reward},index=[0])
            
            Pannel_Data = Pandas_Data.sort_values(["Action","Current Reward","Total Reward","Position","Open Price","High Price","Low Price","Close Price","Volumns"])
            
            print(Pannel_Data) 
            
            if (self.Trading_DateTime_End <= self.data.datetime.datetime()) :
            
                print("************************************************************************"*20)
                print("Total Reward : ", self.Empirical_Reward)
                actions = Agent_A2C.act(states=self.Observation_State)
                Agent_A2C.observe(terminal=True, reward=reward) 
                print("************************************************************************"*20)            
        
################################################################################################            
#                                      Space for Customize Strategy   
################################################################################################            

    return Customize_Object

# %%
import yfinance
class PandasData(backtrader.feed.DataBase):
    '''
    The ``dataname`` parameter inherited from ``feed.DataBase`` is the pandas
    DataFrame
    '''

    params = (
        # Possible values for datetime (must always be present)
        #  None : datetime is the "index" in the Pandas Dataframe
        #  -1 : autodetect position or case-wise equal name
        #  >= 0 : numeric index to the colum in the pandas dataframe
        #  string : column name (as index) in the pandas dataframe
        ('datetime', None),

        # Possible values below:
        #  None : column not present
        #  -1 : autodetect position or case-wise equal name
        #  >= 0 : numeric index to the colum in the pandas dataframe
        #  string : column name (as index) in the pandas dataframe
        ('open', -1),
        ('high', -1),
        ('low', -1),
        ('close', -1),
        ('volume', -1)
    )

# %%
class Trading_Picture_Generator:


    # General
    Trading_Object_Name = ""
    Trading_Level_Multiplier = 1000
    
    Trading_DateTime_Start = datetime(2018,1,1)
    Trading_DateTime_End = datetime(2019,9,22)

    I_Am_Trading_Cerebro_Object = backtrader.Cerebro()
    
    # Parameter Performance Batch
    Parameter_Performance_Batch = []
    
    # Parameter for Customization Strategy
    Customization_Parameter1 = 10 
    Customization_Parameter2 = 20


    def __init__(
        self, 
        Trading_Object_Name_Input, 
        Trading_Level_Multiplier_Input, 
        Trading_DateTime_Interval, 
        Trading_DateTime_Start_Input, 
        Trading_DateTime_End_Input):

        self.Trading_Object_Name = Trading_Object_Name_Input
        self.Trading_Level_Multiplier = Trading_Level_Multiplier_Input

        self.Trading_DateTime_Interval = Trading_DateTime_Interval
        self.Trading_DateTime_Start = Trading_DateTime_Start_Input
        self.Trading_DateTime_End = Trading_DateTime_End_Input



    def Function_RunTrading_Customize(self, Customization_Parameter1, Customization_Parameter2): 

        Cerebro_Object = backtrader.Cerebro()
        Cerebro_Object.broker.setcommission(mult=self.Trading_Level_Multiplier)
        Customize_StrategyObject = Function_For_Build_Customize_Object(Customization_Parameter1, Customization_Parameter2)
        Cerebro_Object.addstrategy(Customize_StrategyObject)

        Im_Data = backtrader.feeds.YahooFinanceData(
            dataname = self.Trading_Object_Name, 
            fromdate=self.Trading_DateTime_Start, 
            todate=self.Trading_DateTime_End)    

        
        Im_RawData = yfinance.download( tickers = self.Trading_Object_Name,  
                                 interval = self.Trading_DateTime_Interval,
                                 start=self.Trading_DateTime_Start, 
                                 end=self.Trading_DateTime_End)
        
        Im_Data = backtrader.feeds.PandasData(dataname=Im_RawData)


        Cerebro_Object.adddata(Im_Data)
        Cerebro_Object.broker.setcash(10000.0)
        Cerebro_Object.run()        
        
        self.Customization_Parameter1 = Customization_Parameter1
        self.Customization_Parameter2 = Customization_Parameter2                                            
        self.Trading_Cerebro_Object = Cerebro_Object


    def Function_Plotting_Customize(self) : 

    #    cerebro.plot()
        figure = matplotlib.pyplot.figure(figsize=(24.0, 15.0))
        figure = self.Trading_Cerebro_Object.plot()[0][0]
        figure.savefig('Trading_Plot/Customize/TradingCustomizeStratey_Object[{}]_Position[{}%]_Multiplier[{}].jpg'.format(
            self.Trading_Object_Name,
            self.Trading_Cerebro_Object.broker.getvalue()/100,
            self.Trading_Level_Multiplier))
        matplotlib.pyplot.close(figure)
        matplotlib.pyplot.close("all")
        
        
    def Function_Batch_MovingAverage(self, Trading_Object_Name_List, Trading_Level_Multiplier_List, Customization_Parameter1_Interval, Customization_Parameter2_Interval):

        try:

            for Specific_Trading_Object_Counter in range(len(Trading_Object_Name_List)):
                for Customization_Parameter1 in range(Customization_Parameter1_Interval[0],Customization_Parameter1_Interval[1]):
                    for Customization_Parameter2 in range(Customization_Parameter2_Interval[0] ,Customization_Parameter2_Interval[1]):

                        self.Trading_Object_Name = Trading_Object_Name_List[Specific_Trading_Object_Counter]
                        self.Trading_Level_Multiplier = Trading_Level_Multiplier_List[Specific_Trading_Object_Counter]
                        self.Function_RunTrading_Customize(Customization_Parameter1 , Customization_Parameter2)
                        self.Parameter_Performance_Batch.append([
                            self.Trading_Object_Name,
                            self.Trading_Cerebro_Object.broker.getvalue()/100,
                            self.Customization_Parameter1,
                            self.Customization_Parameter2])                                            
                        self.Function_Plotting_Customize()
                        
                    self.Function_Plotting_StrategyCombination()

        except:
            
            print(sys.exc_info())
            
            
    def Function_Plotting_StrategyCombination(self) :
        
        X_axsis = numpy.array([])
        Y_axsis = numpy.array([])
        Z_axsis = numpy.array([])
        for data in self.Parameter_Performance_Batch :
            Z_axsis = numpy.append( Z_axsis, data[1])
            Y_axsis = numpy.append( Y_axsis, data[2])
            X_axsis = numpy.append( X_axsis, data[3])
            
        print(X_axsis)        
        print(Y_axsis)
        print(Z_axsis)
        print(self.Parameter_Performance_Batch)        
        ParameterPerformance_Figure = matplotlib.pyplot.figure(figsize=(20,20))
        ax = ParameterPerformance_Figure.add_subplot(111,projection='3d')
        ax.scatter3D(X_axsis, Y_axsis, Z_axsis, c=Z_axsis, s=500, cmap='viridis')

        ParameterPerformance_Figure.savefig('Trading_Plot/Customize/TradingCustomizeStratey_Object[{}]_Parameter1[{}%]_Parameter2[{}].jpg'.format(
            self.Trading_Object_Name,
            self.Customization_Parameter1,
            self.Customization_Parameter2))        
        
        matplotlib.pyplot.show()
        matplotlib.pyplot.close(ParameterPerformance_Figure)
        matplotlib.pyplot.close("all")

# %%
# Customize
I_Am_Trading_Instance = Trading_Picture_Generator("TSM", 1000, "1h",datetime(2017,1,1), datetime(2020,1,1))

# %%
I_Am_Trading_Instance.Function_RunTrading_Customize("I_AM_Input1","I_AM_Input2")
I_Am_Trading_Instance.Function_Plotting_Customize()
# Out:
# ============================================2017-01-03 23:59:59.999989============================================
# Holding
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       2        26.15             0.0       26.33      25.93        26.1
#
#    Position  Total Reward    Volumns
# 0   10000.0           0.0  7039303.0
# ============================================2017-01-04 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        26.14             0.0       26.28      26.05       26.22
#
#    Position  Total Reward    Volumns
# 0   10000.0           0.0  4922568.0
# ============================================2017-01-05 23:59:59.999989============================================
# Selling
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       1        26.59            0.24       26.68      26.34       26.35
#
#    Position  Total Reward    Volumns
# 0  10000.24          0.24  5352865.0
# ============================================2017-01-06 23:59:59.999989============================================
# Selling
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       1        26.44          179.76       26.63      26.28       26.53
#
#    Position  Total Reward    Volumns
# 0   10180.0         180.0  5468313.0
# ============================================2017-01-09 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0         26.8           -0.22       26.89      26.52       26.58
#
#    Position  Total Reward    Volumns
# 0  10179.78        179.78  9383458.0
# ============================================2017-01-10 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        26.83         -219.78       27.03      26.68        26.8
#
#    Position  Total Reward    Volumns
# 0    9960.0         -40.0  8498319.0
# ============================================2017-01-11 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        26.92            0.35       26.94      26.52       26.57
#
#    Position  Total Reward    Volumns
# 0   9960.35        -39.65  8369757.0
# ============================================2017-01-12 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        26.13           -0.82       26.64      25.86       26.16
#
#    Position  Total Reward     Volumns
# 0   9959.53        -40.47  14607200.0
# ============================================2017-01-13 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        26.27            0.23       26.45      26.07       26.32
#
#    Position  Total Reward     Volumns
# 0   9959.76        -40.24  10996816.0
# ============================================2017-01-17 23:59:59.999989============================================
# Selling
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       1        26.43            0.49       26.45      26.28       26.42
#
#    Position  Total Reward    Volumns
# 0   9960.25        -39.75  8607938.0
# ============================================2017-01-18 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        26.31         -7.9225       26.48      26.27       26.36
#
#     Position  Total Reward    Volumns
# 0  9952.3275      -47.6725  8622509.0
# ============================================2017-01-19 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        26.44            0.52       26.49      26.22       26.31
#
#     Position  Total Reward    Volumns
# 0  9952.8475      -47.1525  9519641.0
# ============================================2017-01-20 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        26.83            1.96        27.0      26.38       26.43
#
#     Position  Total Reward    Volumns
# 0  9954.8075      -45.1925  8293651.0
# ============================================2017-01-23 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.06            1.17        27.2      26.95       27.04
#
#     Position  Total Reward    Volumns
# 0  9955.9775      -44.0225  7800923.0
# ============================================2017-01-24 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0         27.5             2.9       27.57      27.22       27.24
#
#     Position  Total Reward    Volumns
# 0  9958.8775      -41.1225  8085397.0
# ============================================2017-01-25 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.93            3.19       27.95       27.6       27.75
#
#     Position  Total Reward    Volumns
# 0  9962.0675      -37.9325  8995754.0
# ============================================2017-01-26 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.76           -1.49       28.06      27.67       27.89
#
#     Position  Total Reward    Volumns
# 0  9960.5775      -39.4225  9312843.0
# ============================================2017-01-27 23:59:59.999989============================================
# Holding
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       2        27.88            1.15       27.97      27.66       27.81
#
#     Position  Total Reward    Volumns
# 0  9961.7275      -38.2725  6705175.0
# ============================================2017-01-30 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.83            -0.5       27.84       27.6       27.72
#
#     Position  Total Reward    Volumns
# 0  9961.2275      -38.7725  8129670.0
# ============================================2017-01-31 23:59:59.999989============================================
# Holding
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       2        27.58           -2.61        27.8      27.42       27.69
#
#     Position  Total Reward    Volumns
# 0  9958.6175      -41.3825  7020024.0
# ============================================2017-02-01 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.73            1.65       27.93      27.51       27.87
#
#     Position  Total Reward    Volumns
# 0  9960.2675      -39.7325  5645632.0
# ============================================2017-02-02 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.46           -2.91       27.56      27.32        27.4
#
#     Position  Total Reward    Volumns
# 0  9957.3575      -42.6425  6495128.0
# ============================================2017-02-03 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.63            2.05       27.73      27.48       27.62
#
#     Position  Total Reward    Volumns
# 0  9959.4075      -40.5925  5883477.0
# ============================================2017-02-06 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.54           -1.24       27.61      27.39       27.61
#
#     Position  Total Reward    Volumns
# 0  9958.1675      -41.8325  3949555.0
# ============================================2017-02-07 23:59:59.999989============================================
# Selling
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       1        27.23           -4.69       27.63      27.21       27.58
#
#     Position  Total Reward    Volumns
# 0  9953.4775      -46.5225  6959946.0
# ============================================2017-02-08 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.06        212.7215       27.39      27.02       27.38
#
#     Position  Total Reward    Volumns
# 0  10166.199       166.199  8716437.0
# ============================================2017-02-09 23:59:59.999989============================================
# Selling
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       1        26.95           -1.65       27.21      26.92       27.06
#
#     Position  Total Reward    Volumns
# 0  10164.549       164.549  9579944.0
# ============================================2017-02-10 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0         27.4          8.6634       27.49      27.08       27.16
#
#      Position  Total Reward    Volumns
# 0  10173.2124      173.2124  7565096.0
# ============================================2017-02-13 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.27           12.85       28.37       27.6        27.6
#
#      Position  Total Reward     Volumns
# 0  10186.0624      186.0624  11436975.0
# ============================================2017-02-14 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.95           -4.93       28.08      27.76       28.08
#
#      Position  Total Reward    Volumns
# 0  10181.1324      181.1324  5838082.0
# ============================================2017-02-15 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.33            6.31       28.37       28.1        28.1
#
#      Position  Total Reward    Volumns
# 0  10187.4424      187.4424  5130375.0
# ============================================2017-02-16 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.84            9.21       28.99      28.22        28.3
#
#      Position  Total Reward     Volumns
# 0  10196.6524      196.6524  14792029.0
# ============================================2017-02-17 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.85            0.39       28.89      28.57       28.64
#
#      Position  Total Reward    Volumns
# 0  10197.0424      197.0424  8426808.0
# ============================================2017-02-21 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.84           -0.25       28.97       28.7        28.9
#
#      Position  Total Reward    Volumns
# 0  10196.7924      196.7924  6137126.0
# ============================================2017-02-22 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.61           -4.72       28.73      28.47       28.73
#
#      Position  Total Reward    Volumns
# 0  10192.0724      192.0724  5936270.0
# ============================================2017-02-23 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.33           -6.23       28.68      28.31       28.68
#
#      Position  Total Reward    Volumns
# 0  10185.8424      185.8424  5930665.0
# ============================================2017-02-24 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.48            3.58       28.48      28.08        28.2
#
#      Position  Total Reward    Volumns
# 0  10189.4224      189.4224  4132703.0
# ============================================2017-02-27 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.13           -8.31       28.39      28.09       28.39
#
#      Position  Total Reward    Volumns
# 0  10181.1124      181.1124  6547920.0
# ============================================2017-02-28 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.08            -1.3       28.26      28.01       28.18
#
#      Position  Total Reward    Volumns
# 0  10179.8124      179.8124  6770857.0
# ============================================2017-03-01 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.17            2.39       28.19      27.89       28.03
#
#      Position  Total Reward    Volumns
# 0  10182.2024      182.2024  5503732.0
# ============================================2017-03-02 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.54          -16.67       27.87      27.47       27.83
#
#      Position  Total Reward    Volumns
# 0  10165.5324      165.5324  9595747.0
# ============================================2017-03-03 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.52           -0.56       27.59      27.25       27.54
#
#      Position  Total Reward    Volumns
# 0  10164.9724      164.9724  6860414.0
# ============================================2017-03-06 23:59:59.999989============================================
# Holding
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       2        27.52            0.04        27.6       27.4       27.48
#
#      Position  Total Reward    Volumns
# 0  10165.0124      165.0124  6128160.0
# ============================================2017-03-07 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.93           11.89       28.01      27.62       27.67
#
#      Position  Total Reward    Volumns
# 0  10176.9024      176.9024  7861673.0
# ============================================2017-03-08 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.85           -2.55       28.12      27.84       28.08
#
#      Position  Total Reward    Volumns
# 0  10174.3524      174.3524  5075789.0
# ============================================2017-03-09 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.64           -6.22       27.71      27.41       27.56
#
#      Position  Total Reward    Volumns
# 0  10168.1324      168.1324  6860414.0
# ============================================2017-03-10 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.71            2.34       27.73       27.5       27.54
#
#      Position  Total Reward    Volumns
# 0  10170.4724      170.4724  6338768.0
# ============================================2017-03-13 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0         28.1           12.68       28.17      27.87        27.9
#
#      Position  Total Reward    Volumns
# 0  10183.1524      183.1524  4444973.0
# ============================================2017-03-14 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        27.84           -8.74       28.08      27.84        28.0
#
#      Position  Total Reward    Volumns
# 0  10174.4124      174.4124  6688362.0
# ============================================2017-03-15 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.47           21.89       28.58      27.96        28.0
#
#      Position  Total Reward    Volumns
# 0  10196.3024      196.3024  5123874.0
# ============================================2017-03-16 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.92            15.9       28.97      28.73       28.77
#
#      Position  Total Reward    Volumns
# 0  10212.2024      212.2024  7273225.0
# ============================================2017-03-17 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        29.08            5.76       29.23      28.94       29.08
#
#      Position  Total Reward    Volumns
# 0  10217.9624      217.9624  6949074.0
# ============================================2017-03-20 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        29.31            8.56       29.54      29.18       29.26
#
#      Position  Total Reward    Volumns
# 0  10226.5224      226.5224  5746285.0
# ============================================2017-03-21 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.98          -13.22       29.91      28.94       29.66
#
#      Position  Total Reward     Volumns
# 0  10213.3024      213.3024  10266915.0
# ============================================2017-03-22 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        29.17            7.52       29.31      28.98       29.06
#
#      Position  Total Reward    Volumns
# 0  10220.8224      220.8224  7524856.0
# ============================================2017-03-23 23:59:59.999989============================================
# Holding
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       2        29.05           -4.72       29.14      28.88       28.97
#
#      Position  Total Reward    Volumns
# 0  10216.1024      216.1024  6624138.0
# ============================================2017-03-24 23:59:59.999989============================================
# Holding
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       2        29.27            9.02       29.53      29.09        29.2
#
#      Position  Total Reward    Volumns
# 0  10225.1224      225.1224  6612929.0
# ============================================2017-03-27 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        29.59           13.12       29.67      29.25       29.31
#
#      Position  Total Reward    Volumns
# 0  10238.2424      238.2424  6345718.0
# ============================================2017-03-28 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        29.75            6.55       29.83      29.56       29.76
#
#      Position  Total Reward    Volumns
# 0  10244.7924      244.7924  5074108.0
# ============================================2017-03-29 23:59:59.999989============================================
# Selling
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       1        29.38          -15.56       29.42      29.24        29.4
#
#      Position  Total Reward    Volumns
# 0  10229.2324      229.2324  4577458.0
# ============================================2017-03-30 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0         29.5     1305.290409       29.58      29.25        29.3
#
#        Position  Total Reward    Volumns
# 0  11534.522809   1534.522809  4360797.0
# ============================================2017-03-31 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0         29.3           -8.27       29.39      29.06       29.17
#
#        Position  Total Reward    Volumns
# 0  11526.252809   1526.252809  5440067.0
# ============================================2017-04-03 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        29.34            1.67       29.44      29.18       29.39
#
#        Position  Total Reward    Volumns
# 0  11527.922809   1527.922809  4800732.0
# ============================================2017-04-04 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        29.32           -0.82        29.4      29.24       29.26
#
#        Position  Total Reward    Volumns
# 0  11527.102809   1527.102809  4210602.0
# ============================================2017-04-05 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        29.35             1.2       29.74      29.33        29.5
#
#        Position  Total Reward    Volumns
# 0  11528.302809   1528.302809  5730817.0
# ============================================2017-04-06 23:59:59.999989============================================
# Selling
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       1        29.32           -1.39       29.39       29.2       29.33
#
#        Position  Total Reward    Volumns
# 0  11526.912809   1526.912809  4473106.0
# ============================================2017-04-07 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        29.33     1179.249089       29.48      29.24       29.32
#
#        Position  Total Reward    Volumns
# 0  12706.161898   2706.161898  3773132.0
# ============================================2017-04-10 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        29.01          -15.04       29.33      28.92       29.33
#
#        Position  Total Reward    Volumns
# 0  12691.121898   2691.121898  5533771.0
# ============================================2017-04-11 23:59:59.999989============================================
# Selling
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       1        28.91           -4.96       29.17      28.53       29.17
#
#        Position  Total Reward    Volumns
# 0  12686.161898   2686.161898  7054434.0
# ============================================2017-04-12 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0         28.8      777.826627       29.12      28.57       28.97
#
#        Position  Total Reward    Volumns
# 0  13463.988526   3463.988526  6878124.0
# ============================================2017-04-13 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0         28.4          -19.04       28.95      28.39       28.64
#
#        Position  Total Reward    Volumns
# 0  13444.948526   3444.948526  9843008.0
# ============================================2017-04-17 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.58            8.63       28.61      28.34       28.59
#
#        Position  Total Reward    Volumns
# 0  13453.578526   3453.578526  7755080.0
# ============================================2017-04-18 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.36          -10.76       28.42      28.22       28.34
#
#        Position  Total Reward    Volumns
# 0  13442.818526   3442.818526  6129504.0
# ============================================2017-04-19 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0         28.2           -8.28       28.51      28.09       28.48
#
#        Position  Total Reward    Volumns
# 0  13434.538526   3434.538526  5311954.0
# ============================================2017-04-20 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.36            8.18       28.43      28.23       28.34
#
#        Position  Total Reward    Volumns
# 0  13442.718526   3442.718526  4749845.0
# ============================================2017-04-21 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        28.62           13.51       28.67      28.51       28.63
#
#        Position  Total Reward    Volumns
# 0  13456.228526   3456.228526  5077919.0
# ============================================2017-04-24 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        29.17           29.25       29.26      28.99       29.07
#
#        Position  Total Reward    Volumns
# 0  13485.478526   3485.478526  6407924.0
# ============================================2017-04-25 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0         29.5           18.09        29.6      29.22       29.23
#
#        Position  Total Reward    Volumns
# 0  13503.568526   3503.568526  6292814.0
# ============================================2017-04-26 23:59:59.999989============================================
# Holding
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       2        29.44           -3.36       29.54      29.28        29.5
#
#        Position  Total Reward    Volumns
# 0  13500.208526   3500.208526  6756174.0
# ============================================2017-04-27 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        29.46            1.12       29.71      29.45       29.54
#
#        Position  Total Reward    Volumns
# 0  13501.328526   3501.328526  6305479.0
# ============================================2017-04-28 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0         29.5            2.16       29.66      29.48       29.58
#
#        Position  Total Reward    Volumns
# 0  13503.488526   3503.488526  5885047.0
# ============================================2017-05-01 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0         29.8           17.32       29.81      29.57       29.58
#
#        Position  Total Reward    Volumns
# 0  13520.808526   3520.808526  4500343.0
# ============================================2017-05-02 23:59:59.999989============================================
# Selling
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       1        30.27           27.58       30.33      29.95       29.95
#
#        Position  Total Reward    Volumns
# 0  13548.388526   3548.388526  6713134.0
# ============================================2017-05-03 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        30.59      1896.04494       30.59      30.19       30.23
#
#        Position  Total Reward    Volumns
# 0  15444.433466   5444.433466  7465675.0
# ============================================2017-05-04 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        30.46           -7.58        30.5      30.31        30.5
#
#        Position  Total Reward    Volumns
# 0  15436.853466   5436.853466  6385845.0
# ============================================2017-05-05 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        30.71           14.98       30.73      30.36       30.48
#
#        Position  Total Reward    Volumns
# 0  15451.833466   5451.833466  5884262.0
# ============================================2017-05-08 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        31.21           30.25       31.32       30.9       30.96
#
#        Position  Total Reward    Volumns
# 0  15482.083466   5482.083466  7741629.0
# ============================================2017-05-09 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        31.59           23.43       31.64      31.34       31.34
#
#        Position  Total Reward    Volumns
# 0  15505.513466   5505.513466  8179884.0
# ============================================2017-05-10 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        31.59            0.12       31.79       31.3       31.47
#
#        Position  Total Reward     Volumns
# 0  15505.633466   5505.633466  11137595.0
# ============================================2017-05-11 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        31.73            8.77       31.94      31.56       31.78
#
#        Position  Total Reward    Volumns
# 0  15514.403466   5514.403466  7452449.0
# ============================================2017-05-12 23:59:59.999989============================================
# Holding
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       2        31.56          -10.99       31.69      31.45       31.67
#
#        Position  Total Reward    Volumns
# 0  15503.413466   5503.413466  5497791.0
# ============================================2017-05-15 23:59:59.999989============================================
# Selling
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       1        31.28           -18.2       31.57      31.12       31.55
#
#        Position  Total Reward     Volumns
# 0  15485.213466   5485.213466  10967225.0
# ============================================2017-05-16 23:59:59.999989============================================
# Selling
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       1        31.25     2581.076716       31.25      31.05       31.24
#
#        Position  Total Reward    Volumns
# 0  18066.290182   8066.290182  6776911.0
# ============================================2017-05-17 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0        30.71     2359.006716       31.06      30.68       31.05
#
#        Position  Total Reward    Volumns
# 0  20425.296898  10425.296898  9110417.0
# ============================================2017-05-18 23:59:59.999989============================================
# Selling
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       1        31.14            27.5       31.22       30.7       30.73
#
#        Position  Total Reward    Volumns
# 0  20452.796898  10452.796898  9307240.0
# ============================================2017-05-19 23:59:59.999989============================================
# Buying
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       0         31.4     2627.117548       31.43      31.17        31.3
#
#        Position  Total Reward    Volumns
# 0  23079.914446  13079.914446  8163520.0
# ============================================2017-05-22 23:59:59.999989============================================
# Buying
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-208-5a9ba88108e0> in <module>()
# ----> 1 I_Am_Trading_Instance.Function_RunTrading_Customize("I_AM_Input1","I_AM_Input2")
#       2 I_Am_Trading_Instance.Function_Plotting_Customize()
#
# <ipython-input-204-b5b88a6fe08f> in Function_RunTrading_Customize(self, Customization_Parameter1, Customization_Parameter2)
#      47         Cerebro_Object.adddata(Im_Data)
#      48         Cerebro_Object.broker.setcash(10000.0)
# ---> 49         Cerebro_Object.run()
#      50
#      51         self.Customization_Parameter1 = Customization_Parameter1
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\backtrader\cerebro.py in run(self, **kwargs)
#    1125             # let's skip process "spawning"
#    1126             for iterstrat in iterstrats:
# -> 1127                 runstrat = self.runstrategies(iterstrat)
#    1128                 self.runstrats.append(runstrat)
#    1129                 if self._dooptimize:
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\backtrader\cerebro.py in runstrategies(self, iterstrat, predata)
#    1291                     self._runonce_old(runstrats)
#    1292                 else:
# -> 1293                     self._runonce(runstrats)
#    1294             else:
#    1295                 if self.p.oldsync:
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\backtrader\cerebro.py in _runonce(self, runstrats)
#    1693
#    1694             for strat in runstrats:
# -> 1695                 strat._oncepost(dt0)
#    1696                 if self._event_stop:  # stop if requested
#    1697                     return
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\backtrader\strategy.py in _oncepost(self, dt)
#     307         minperstatus = self._getminperstatus()
#     308         if minperstatus < 0:
# --> 309             self.next()
#     310         elif minperstatus == 0:
#     311             self.nextstart()  # only called for the 1st value
#
# <ipython-input-203-e3e90cb92cc9> in next(self)
#      76                                     "Total Reward": self.Empirical_Reward},index=[0])
#      77
# ---> 78             Pannel_Data = Pandas_Data.sort_values(["Action","Current Reward","Total Reward","Position","Open Price","High Price","Low Price","Close Price","Volumns"])
#      79
#      80             print(Pannel_Data)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4980
#    4981             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
# -> 4982             indexer = lexsort_indexer(keys, orders=ascending, na_position=na_position)
#    4983             indexer = ensure_platform_int(indexer)
#    4984         else:
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\sorting.py in lexsort_indexer(keys, orders, na_position)
#     207         # create the Categorical
#     208         else:
# --> 209             c = Categorical(key, ordered=True)
#     210
#     211         if na_position not in ["last", "first"]:
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\arrays\categorical.py in __init__(self, values, categories, ordered, dtype, fastpath)
#     401
#     402             # we're inferring from values
# --> 403             dtype = CategoricalDtype(categories, dtype._ordered)
#     404
#     405         elif is_categorical_dtype(values):
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\dtypes\dtypes.py in __init__(self, categories, ordered)
#     224
#     225     def __init__(self, categories=None, ordered: OrderedType = ordered_sentinel):
# --> 226         self._finalize(categories, ordered, fastpath=False)
#     227
#     228     @classmethod
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\dtypes\dtypes.py in _finalize(self, categories, ordered, fastpath)
#     345
#     346         if categories is not None:
# --> 347             categories = self.validate_categories(categories, fastpath=fastpath)
#     348
#     349         self._categories = categories
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\dtypes\dtypes.py in validate_categories(categories, fastpath)
#     524                 raise ValueError("Categorial categories cannot be null")
#     525
# --> 526             if not categories.is_unique:
#     527                 raise ValueError("Categorical categories must be unique")
#     528
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\numeric.py in is_unique(self)
#     481     @cache_readonly
#     482     def is_unique(self):
# --> 483         return super().is_unique and self._nan_idxs.size < 2
#     484
#     485     @Appender(Index.isin.__doc__)
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in is_unique(self)
#    1799         Return if the index has unique values.
#    1800         """
# -> 1801         return self._engine.is_unique
#    1802
#    1803     @property
#
# KeyboardInterrupt:

# %%
## Taiwan Market ##
#Batch
I_Am_Trading_Instance.Function_Batch_MovingAverage(
    Trading_Object_Name_List = ["TSM"], 
    Trading_Level_Multiplier_List = [1000],
    Customization_Parameter1_Interval = [0,10], 
    Customization_Parameter2_Interval = [0,10])
# Out:
# ============================================2017-01-03 23:59:59.999989============================================
# Holding
#    Action  Close Price  Current Reward  High Price  Low Price  Open Price  \
# 0       2        26.15             0.0       26.33      25.93        26.1
#
#    Position  Total Reward    Volumns
# 0   10000.0           0.0  7039303.0
# (<class 'AttributeError'>, AttributeError("'Lines_LineSeries_LineIterator_DataAccessor_Strateg' object has no attribute 'Trading_DateTime_End'",), <traceback object at 0x000001A6D576EA48>)
