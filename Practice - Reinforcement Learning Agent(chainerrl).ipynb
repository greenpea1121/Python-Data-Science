# %%
! pip install -U gym chainerrl
# Out:
# Requirement already up-to-date: gym in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (0.17.1)
# Requirement already satisfied, skipping upgrade: scipy in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from gym) (1.1.0)
# Requirement already satisfied, skipping upgrade: pyglet<=1.5.0,>=1.4.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from gym) (1.5.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.10.4 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from gym) (1.16.2)
# Requirement already satisfied, skipping upgrade: six in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from gym) (1.11.0)
# Requirement already satisfied, skipping upgrade: cloudpickle<1.4.0,>=1.2.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from gym) (1.2.2)
# Requirement already satisfied, skipping upgrade: future in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import gym
import numpy as np

# %%
# Agent 函示庫
import chainer
import chainerrl

# %%
# 產生環境
I_am_RL_Enviroment = gym.make('CartPole-v0')

# 視覺化 
# I_am_RL_Enviroment.render()
# 已將azure notebook的視覺化取消        


print("Observation Space : ")
print(I_am_RL_Enviroment.observation_space)
obs_size = I_am_RL_Enviroment.observation_space.shape[0]
print("Action Space : ")
print(I_am_RL_Enviroment.action_space)
n_actions = I_am_RL_Enviroment.action_space.n
# Out:
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)

# %%
# agent 參數設定

# %%
# Instance of Value function Q from "chainerrl.q_functions.FCStateQFunctionWithDiscreteAction"
I_Am_Q_Function = chainerrl.q_functions.FCStateQFunctionWithDiscreteAction(obs_size, n_actions,n_hidden_layers=4, n_hidden_channels=50)

# %%
# Instance of training optimizer from chainer.optimizers
optimizer = chainer.optimizers.Adam(eps=1e-2)
# set the oprimizer 
optimizer.setup(I_Am_Q_Function)

# %%
# Set the discount factor that discounts future rewards.
gamma = 0.9

# Use epsilon-greedy for exploration
explorer = chainerrl.explorers.ConstantEpsilonGreedy(
    epsilon=0.3, random_action_func=I_am_RL_Enviroment.action_space.sample)

# DQN uses Experience Replay.
# Specify a replay buffer and its capacity.
replay_buffer = chainerrl.replay_buffer.ReplayBuffer(capacity=10 ** 6)

# Since observations from CartPole-v0 is numpy.float64 while
# Chainer only accepts numpy.float32 by default, specify
# a converter as a feature extractor function phi.
phi = lambda x: x.astype(np.float32, copy=False)

# Now create an agent that will interact with the environment.
I_am_DQN_Agent = chainerrl.agents.DoubleDQN(
    I_Am_Q_Function, optimizer, replay_buffer, gamma, explorer,
    replay_start_size=500, update_interval=1,
    target_update_interval=100, phi=phi)

# %%
for i_episode in range(100): #how many episodes you want to run
    
    Observation_State = I_am_RL_Enviroment.reset() #reset() returns initial observation
    Step_Reward = 0
    Empirical_Reward = 0
    done = False
    
    for Step_T in range(100):
        
        # 視覺化 
        # I_am_RL_Enviroment.render()
        # 已將azure notebook的視覺化取消        

        
        print("I am step : {}".format(Step_T))
        print("============== Current Senario ==============")        
        print("Observation Space : ")
        print(I_am_RL_Enviroment.observation_space)
        print("Action Space : ")
        print(I_am_RL_Enviroment.action_space)

        
        print("============== Current Interaction  ==============")
        print("Current Observation : ")
        print(Observation_State)
        print("Current Action Select : ")
        
        
        # 將隨機行為換成 AI agent 行為 
        # Action_Select = I_am_RL_Enviroment.action_space.sample()
        
        # AI agent 依輸入的狀態與前項回饋產生行為以及訓練         
        Action_Select = I_am_DQN_Agent.act_and_train(Observation_State , Step_Reward)
        print(Action_Select)
        print("============== Current Interaction  ==============")

        
        print("============== Enviroment Interaction Result ==============")
        Observation_State, Step_Reward, Done, Infomation = I_am_RL_Enviroment.step(Action_Select)
        print("New Observation State from Enviroment Interaction  : ")
        print(Observation_State)
        print("Reward from Enviroment Interaction  : ")
        Step_Reward = Step_Reward
        print(Step_Reward)
        Empirical_Reward = Empirical_Reward + Step_Reward
        print("Infomation from Enviroment Interaction  : ")        
        print(Infomation)
        print("============== Enviroment Interaction Result ==============")
        
        if Done :
            print(" End of Step "*10)
            break
    
    print('episode:', i_episode, 'R:', Empirical_Reward, 'statistics:', I_am_DQN_Agent.get_statistics())
    I_am_DQN_Agent.stop_episode_and_train(Observation_State, Step_Reward, done)
# Out:
# I am step : 0
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [ 0.00665969  0.02527673  0.04730677 -0.01603782]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [ 0.00716523 -0.17049061  0.04698601  0.29118768]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 1
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [ 0.00716523 -0.17049061  0.04698601  0.29118768]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [ 0.00375541 -0.36624994  0.05280977  0.5983114 ]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 2
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [ 0.00375541 -0.36624994  0.05280977  0.5983114 ]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.00356958 -0.56206949  0.06477599  0.90715009]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 3
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.00356958 -0.56206949  0.06477599  0.90715009]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.01481097 -0.75800579  0.082919    1.21946898]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 4
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.01481097 -0.75800579  0.082919    1.21946898]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.02997109 -0.95409289  0.10730838  1.53693931]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 5
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.02997109 -0.95409289  0.10730838  1.53693931]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.04905295 -1.15033048  0.13804716  1.8610907 ]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 6
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.04905295 -1.15033048  0.13804716  1.8610907 ]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.07205956 -1.34667012  0.17526898  2.19325546]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 7
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.07205956 -1.34667012  0.17526898  2.19325546]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.09899296 -1.54299938  0.21913409  2.53450328]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
#  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step
# episode: 0 R: 8.0 statistics: [('average_q', 0.0008348510943033422), ('average_loss', 0), ('n_updates', 0)]
# I am step : 0
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.0451372  -0.03804506  0.02759463 -0.0023531 ]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.0458981  -0.23355166  0.02754756  0.29890695]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 1
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.0458981  -0.23355166  0.02754756  0.29890695]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.05056914 -0.42905523  0.0335257   0.600149  ]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 2
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.05056914 -0.42905523  0.0335257   0.600149  ]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.05915024 -0.62462978  0.04552868  0.90320068]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 3
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.05915024 -0.62462978  0.04552868  0.90320068]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.07164284 -0.82033789  0.0635927   1.20983945]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 4
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.07164284 -0.82033789  0.0635927   1.20983945]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.0880496  -1.01622076  0.08778949  1.5217535 ]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 5
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.0880496  -1.01622076  0.08778949  1.5217535 ]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.10837401 -1.21228691  0.11822456  1.84049711]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 6
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.10837401 -1.21228691  0.11822456  1.84049711]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.13261975 -1.40849909  0.1550345   2.16743803]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 7
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.13261975 -1.40849909  0.1550345   2.16743803]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.16078973 -1.60475888  0.19838326  2.50369464]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 8
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.16078973 -1.60475888  0.19838326  2.50369464]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.19288491 -1.80088916  0.24845715  2.85006272]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
#  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step
# episode: 1 R: 9.0 statistics: [('average_q', 0.002037184045962103), ('average_loss', 0), ('n_updates', 0)]
# I am step : 0
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [ 0.01046072  0.04308032  0.00818698 -0.04480016]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [ 0.01132233 -0.15215806  0.00729098  0.25045455]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 1
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [ 0.01132233 -0.15215806  0.00729098  0.25045455]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [ 0.00827916 -0.34738337  0.01230007  0.54542826]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 2
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [ 0.00827916 -0.34738337  0.01230007  0.54542826]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [ 0.0013315  -0.54267597  0.02320863  0.84196113]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 3
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [ 0.0013315  -0.54267597  0.02320863  0.84196113]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.00952202 -0.7381069   0.04004786  1.1418513 ]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 4
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.00952202 -0.7381069   0.04004786  1.1418513 ]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.02428416 -0.93372871  0.06288488  1.44681966]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 5
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.02428416 -0.93372871  0.06288488  1.44681966]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.04295874 -1.12956521  0.09182127  1.75846975]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 6
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.04295874 -1.12956521  0.09182127  1.75846975]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0

# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [ 0.01198741 -0.23887388 -0.02517258  0.28168665]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 1
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [ 0.01198741 -0.23887388 -0.02517258  0.28168665]
# Current Action Select :
# 1
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [ 0.00720994 -0.04340208 -0.01953884 -0.01882812]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 2
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [ 0.00720994 -0.04340208 -0.01953884 -0.01882812]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [ 0.0063419  -0.23823845 -0.01991541  0.2676266 ]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 3
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [ 0.0063419  -0.23823845 -0.01991541  0.2676266 ]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [ 0.00157713 -0.4330706  -0.01456288  0.55396212]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 4
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [ 0.00157713 -0.4330706  -0.01456288  0.55396212]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.00708429 -0.62798506 -0.00348363  0.84202148]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 5
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.00708429 -0.62798506 -0.00348363  0.84202148]
# Current Action Select :
# 1
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.01964399 -0.43281573  0.0133568   0.54824508]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 6
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.01964399 -0.43281573  0.0133568   0.54824508]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.0283003  -0.62812275  0.0243217   0.84510626]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 7
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.0283003  -0.62812275  0.0243217   0.84510626]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.04086276 -0.82356797  0.04122382  1.14533725]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 8
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.04086276 -0.82356797  0.04122382  1.14533725]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.05733412 -1.0192034   0.06413057  1.45065747]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 9
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.05733412 -1.0192034   0.06413057  1.45065747]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.07771818 -1.21505213  0.09314372  1.76266812]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 10
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.07771818 -1.21505213  0.09314372  1.76266812]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.10201923 -1.41109616  0.12839708  2.08280415]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 11
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.10201923 -1.41109616  0.12839708  2.08280415]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.13024115 -1.60726209  0.17005316  2.41227602]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 12
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.13024115 -1.60726209  0.17005316  2.41227602]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.16238639 -1.8034043   0.21829868  2.75200053]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
#  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step
# episode: 98 R: 13.0 statistics: [('average_q', 1.5758834205359027), ('average_loss', 0.017737956203225838), ('n_updates', 598)]
# I am step : 0
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [ 0.03593819  0.02641105 -0.02817055 -0.02368802]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [ 0.03646641 -0.16829582 -0.02864431  0.25997536]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 1
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [ 0.03646641 -0.16829582 -0.02864431  0.25997536]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [ 0.03310049 -0.3629974  -0.0234448   0.54348765]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 2
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [ 0.03310049 -0.3629974  -0.0234448   0.54348765]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [ 0.02584054 -0.55778217 -0.01257505  0.82869236]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 3
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [ 0.02584054 -0.55778217 -0.01257505  0.82869236]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [ 0.0146849  -0.75272996  0.0039988   1.11739397]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 4
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [ 0.0146849  -0.75272996  0.0039988   1.11739397]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-3.69698461e-04 -9.47904161e-01  2.63466794e-02  1.41132857e+00]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 5
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-3.69698461e-04 -9.47904161e-01  2.63466794e-02  1.41132857e+00]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.01932778 -1.14334267  0.05457325  1.71212962]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 6
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.01932778 -1.14334267  0.05457325  1.71212962]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.04219464 -1.33904713  0.08881584  2.02128585]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 7
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.04219464 -1.33904713  0.08881584  2.02128585]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.06897558 -1.5349698   0.12924156  2.34008905]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 8
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.06897558 -1.5349698   0.12924156  2.34008905]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.09967497 -1.73099789  0.17604334  2.66957018]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
# I am step : 9
# ============== Current Senario ==============
# Observation Space :
# Box(4,)
# Action Space :
# Discrete(2)
# ============== Current Interaction  ==============
# Current Observation :
# [-0.09967497 -1.73099789  0.17604334  2.66957018]
# Current Action Select :
# 0
# ============== Current Interaction  ==============
# ============== Enviroment Interaction Result ==============
# New Observation State from Enviroment Interaction  :
# [-0.13429493 -1.9269353   0.22943474  3.0104236 ]
# Reward from Enviroment Interaction  :
# 1.0
# Infomation from Enviroment Interaction  :
# {}
# ============== Enviroment Interaction Result ==============
#  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step  End of Step
# episode: 99 R: 10.0 statistics: [('average_q', 1.6229963695952887), ('average_loss', 0.02412196040987102), ('n_updates', 608)]
