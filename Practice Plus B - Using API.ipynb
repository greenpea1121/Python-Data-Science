# %%
# API Practice - Restful API

# Example : https://developer.fugle.tw/realtime/document#/
import requests
print(requests)
# Out:
# <module 'requests' from '/home/nbuser/anaconda3_501/lib/python3.6/site-packages/requests/__init__.py'>

# %%
I_Am_Http_Response= requests.get("https://api.fugle.tw/realtime/v0/intraday/chart?symbolId=2884&apiToken=demo")

print(I_Am_Http_Response)
print(dir(I_Am_Http_Response))
print(vars(I_Am_Http_Response))
# Out:
# <Response [200]>
# ...

# %%
I_Am_Http_Response1= requests.get("https://api.fugle.tw/realtime/v0/intraday/chart?symbolId=2884&apiToken=demo")
I_Am_Http_Response2= requests.get("https://api.fugle.tw/realtime/v0/intraday/quote?symbolId=2884&apiToken=demo")
I_Am_Http_Response3= requests.get("https://api.fugle.tw/realtime/v0/intraday/meta?symbolId=2884&apiToken=demo")
I_Am_Http_Response4= requests.get("https://api.fugle.tw/realtime/v0/intraday/trades?symbolId=2884&apiToken=demo")

# %%
print(I_Am_Http_Response4.text)
# Out:
# {"apiVersion":"0.1.0","data":{"info":{"countryCode":"TW","date":"2019-12-30","lastUpdatedAt":"2019-12-30T05:33:15.975Z","mode":"twse-sem","symbolId":"2884","timeZone":"Asia/Taipei"},"trades":[{"at":"2019-12-30T05:30:00.000Z","price":28,"unit":2664,"volume":2664000,"serial":1012713},{"at":"2019-12-30T05:24:55.993Z","price":27.9,"unit":41,"volume":41000,"serial":988703},{"at":"2019-12-30T05:24:40.952Z","price":27.9,"unit":64,"volume":64000,"serial":987546},{"at":"2019-12-30T05:24:30.924Z","price":27.9,"unit":7,"volume":7000,"serial":986733},{"at":"2019-12-30T05:24:00.838Z","price":27.9,"unit":2,"volume":2000,"serial":984182},{"at":"2019-12-30T05:23:55.823Z","price":27.9,"unit":15,"volume":15000,"serial":983782},{"at":"2019-12-30T05:23:40.779Z","price":27.9,"unit":116,"volume":116000,"serial":982507},{"at":"2019-12-30T05:23:35.766Z","price":27.9,"unit":2,"volume":2000,"serial":982082},{"at":"2019-12-30T05:23:30.751Z","price":27.95,"unit":1,"volume":1000,"serial":981708},{"at":"2019-12-3
# ...

# %%
print(I_Am_Http_Response)
print(I_Am_Http_Response.text)
# Out:
# <Response [200]>
# ...

# %%
# API Practice - Taiwan Stock

#installation 安裝
! pip install -U --user twstock
# Out:
# ...
#      |████████████████████████████████| 1.9MB 3.4MB/s eta 0:00:01
# ...

# %%
import twstock

twstock.__update_codes()

# %%
#個股資料
print(twstock.codes['1101'])        

# Fetching Data (Default 30 days)
I_am_stock_data = twstock.Stock('1101')
# Out:
# StockCodeInfo(type='股票', code='1101', name='台泥', ISIN='TW0001101004', start='1962/02/09', market='上市', group='水泥工業', CFI='ESVUFR')

# %%
# 區間設定
I_am_stock_data.fetch_from(2019, 10)

# Price 價格資料
print(I_am_stock_data.price)

# Price 交易量
print(I_am_stock_data.capacity)

# Each Data from Starting period 逐筆資料 起始時間為linst 0  
print(I_am_stock_data.data[62])
# Out:
# [39.65, 39.25, 39.0, 38.9, 39.3, 39.75, 39.5, 39.95, 40.0, 40.0, 40.1, 40.95, 41.5, 41.4, 40.95, 41.0, 40.85, 40.75, 40.65, 40.35, 40.45, 40.55, 40.95, 40.9, 40.8, 40.95, 40.9, 40.35, 40.65, 41.0, 41.15, 41.7, 42.1, 42.1, 42.65, 42.35, 42.1, 41.95, 41.8, 41.95, 42.0, 41.4, 41.35, 41.85, 41.75, 41.65, 41.75, 42.05, 42.1, 42.15, 42.3, 42.55, 42.8, 42.95, 43.0, 43.0, 42.95, 43.25, 43.15, 43.1, 43.05, 43.25, 43.65]
# ...

# %%
# 即時資料

print("Single Object")
print(twstock.realtime.get('1101'))    # 擷取當前台積電股票資訊

print("Multiple Object")
print(twstock.realtime.get(['2330', '2337', '2409']))  # 擷取當前三檔資訊
# Out:
# Single Object
# {'timestamp': 1577687400.0, 'info': {'code': '1101', 'channel': '1101.tw', 'name': '台泥', 'fullname': '台灣水泥股份有限公司', 'time': '2019-12-30 06:30:00'}, 'realtime': {'latest_trade_price': '43.65', 'trade_volume': '791', 'accumulate_trade_volume': '20759', 'best_bid_price': ['43.60', '43.55', '43.50', '43.45', '43.40'], 'best_bid_volume': ['72', '550', '482', '216', '380'], 'best_ask_price': ['43.65', '43.70', '43.75', '43.80', '43.85'], 'best_ask_volume': ['86', '106', '193', '1621', '1031'], 'open': '43.35', 'high': '43.90', 'low': '43.30'}, 'success': True}
# Multiple Object
# ...

# %%
! pip install -U yfinance

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# get stock info
msft.info

# get historical market data
hist = msft.history(period="max")

# show actions (dividends, splits)
msft.actions

# show dividends
msft.dividends

# show splits
msft.splits

# show financials
msft.financials
msft.quarterly_financials

# show major holders
stock.major_holders

# show institutional holders
stock.institutional_holders

# show balance heet
msft.balance_sheet
msft.quarterly_balance_sheet

# show cashflow
msft.cashflow
msft.quarterly_cashflow

# show earnings
msft.earnings
msft.quarterly_earnings

# show sustainability
msft.sustainability

# show analysts recommendations
msft.recommendations

# show next event (earnings, etc)
msft.calendar

# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin

# show options expirations
msft.options

# get option chain for specific expiration
opt = msft.option_chain('YYYY-MM-DD')
# data available via: opt.calls, opt.puts
