# %%
# LSTM
# Build by define Function

def Im_Lstm_Model_Initialization_Funcion(FeatureData_PeriodRange_Start, FeatureData_PeriodRange_End ):

    Im_cute_model = keras.models.Sequential()
        
    Im_cute_model.add(keras.layers.recurrent.LSTM(256, input_shape=(None, 5*( FeatureData_PeriodRange_Start - FeatureData_PeriodRange_End )), return_sequences=True))
    Im_cute_model.add(keras.layers.core.Dropout(0.1))

    Im_cute_model.add(keras.layers.recurrent.LSTM(512, return_sequences=True))
    Im_cute_model.add(keras.layers.core.Dropout(0.2))

    Im_cute_model.add(keras.layers.recurrent.SimpleRNN(256, return_sequences=True))
    Im_cute_model.add(keras.layers.core.Dropout(0.2))

    Im_cute_model.add(keras.layers.core.Dense(units = 512, activation = "relu"))
    Im_cute_model.add(keras.layers.core.Dropout(0.2))

    Im_cute_model.add(keras.layers.recurrent.LSTM(256, return_sequences=True))
    Im_cute_model.add(keras.layers.core.Dropout(0.2))

    Im_cute_model.add(keras.layers.recurrent.LSTM(128, return_sequences=True))
    Im_cute_model.add(keras.layers.core.Dropout(0.1))

    Im_cute_model.add(keras.layers.core.Dense(units = 1, activation = "linear"))

    Im_AdamAMSgrad_Optimizer = keras.optimizers.Adam(amsgrad=True)


    Im_cute_model.compile(loss = "mse", optimizer = Im_AdamAMSgrad_Optimizer )

    return Im_cute_model

# Initialize  model 
# 產生模型
Im_cute_model = Im_Lstm_Model_Initialization_Funcion(-10, -60)

# Prediction 
# 預測
def Im_prediction_function(Im_train_input):

    Im_cute_prediction = Im_cute_model.predict(Im_train_input)

    return Im_cute_prediction


# Training 
# 訓練
def Im_training_function(Im_train_input_set, Im_train_label_set, Im_train_epochs): 

    Im_cute_model.fit(
        Im_train_input_set,
        Im_train_label_set,
#        batch_size = 1,
        epochs = Im_train_epochs,
        verbose = 2,
#        validation_split = 0.05
    )
    return Im_cute_model.evaluate(x =  Im_train_input_set, y =  Im_train_label_set)

# evaluation
# 衡量模型
def Im_performance_testing_function(Im_train_input_set, Im_train_label_set): 

    return Im_cute_model.evaluate(x =  Im_train_input_set, y =  Im_train_label_set)



######################################################################################################################
######################################################################################################################
######################################################################################################################
######################################################################################################################

# 儲存模型 
# Save model to .h5 file 
Im_cute_model.save("LSTM_BackTrader.h5")
# 讀取模型
# Read model from file
Im_cute_model = keras.models.load_model("LSTM_BackTrader.h5")

# Make some random data
# 隨機產生應用資料
Im_array_training_feature_Instant = numpy.random.rand(1000,1,250)
Im_array_training_label_Instant = numpy.random.rand(1000,1,1)

# Training 
# 訓練
print(Im_training_function(Im_array_training_feature_Instant, Im_array_training_label_Instant, 1))

# Prediction 
# 預測
print(Im_prediction_function(Im_array_training_feature_Instant))

# %%
# DNN
import numpy
import pandas 
#載入中央氣象局資料CSV
I_Am_Hotel_Data_Year106 = pandas.read_csv("DataFolder/106011202.csv")
print(I_Am_Hotel_Data_Year106.loc[,"旅館名稱"])
I_Am_Hotel_Data_Year107 = pandas.read_csv("DataFolder/107011202.csv")

#print(I_Am_Hotel_Data_Year106)
#print(I_Am_Hotel_Data_Year107)
I_Am_Hotel_Data_Year106_Useful = I_Am_Hotel_Data_Year106.loc[:,["客房數","客房住用數","住用率","平均房價","房租收入","餐飲收入","總營業收入","客房部","餐飲部","管理部","其他部門","員工合計"]]
I_Am_Hotel_Data_Year107_Useful = I_Am_Hotel_Data_Year107.loc[:,["客房數","客房住用數","住用率","平均房價","房租收入","餐飲收入","總營業收入","客房部","餐飲部","管理部","其他部門","員工合計"]]

#print(I_Am_Hotel_Data_Year106_Useful.values)
#print(I_Am_Hotel_Data_Year107_Useful.values)

Train_Data = I_Am_Hotel_Data_Year106.loc[:,["客房數","客房住用數","平均房價","客房部","餐飲部","管理部","其他部門","員工合計"]]
Train_Data_Array = Train_Data.replace(to_replace=r',', value='', regex=True).astype('float64').fillna(0.0)
Train_Label = I_Am_Hotel_Data_Year106.loc[:,["房租收入","餐飲收入","總營業收入"]]
Train_Label_Array = Train_Label.replace(to_replace=r',', value='', regex=True).astype('float64').fillna(0.0)

print(Train_Data_Array.values)
print(Train_Label_Array.values)
Test_Data = I_Am_Hotel_Data_Year107.loc[:,["客房數","客房住用數","平均房價","客房部","餐飲部","管理部","其他部門","員工合計"]] 
Test_Data_Array = Test_Data.replace(to_replace=r',', value='', regex=True).astype('float64').fillna(0.0)
Test_Label = I_Am_Hotel_Data_Year107.loc[:,["房租收入","餐飲收入","總營業收入"]] 
Test_Label_Array = Test_Label.replace(to_replace=r',', value='', regex=True).astype('float64').fillna(0.0)
# Out:
#                     地區                                               旅館名稱  \
# 0          臺北地區 Taipei                               圓山大飯店The Grand Hotel
# 1          臺北地區 Taipei                          國賓大飯店The Ambassador Hotel
# 2          臺北地區 Taipei                       台北華國大飯店Imperial Hotel Taipei
# 3          臺北地區 Taipei                         華泰王子大飯店Gloria Prince Hotel
# 4          臺北地區 Taipei                                 國王大飯店Emperor Hotel
# 5          臺北地區 Taipei                        豪景大酒店Hotel Riverview Taipei
# 6          臺北地區 Taipei                          台北凱撒大飯店Caesar Park Taipei
# 7          臺北地區 Taipei                            康華大飯店Golden China Hotel
# 8          臺北地區 Taipei                                神旺大飯店San Want Hotel
# 9          臺北地區 Taipei                                 兄弟大飯店Brother Hotel
# 10         臺北地區 Taipei                                  三德大飯店Santos Hotel
# 11         臺北地區 Taipei                     亞都麗緻大飯店The Landis Taipei Hotel
# ...

# %%
# Basic Practice

#使用keras 模組創建instance 物件實例
Im_model = keras.models.Sequential()

#將產生的類神經網路物件 開始架構結構

#輸入層 input layer
Im_model.add(keras.layers.Dense(units=64, activation='relu', input_dim=8))
Im_model.add(keras.layers.core.Dropout(0.5))
Im_model.add(keras.layers.Dense(units=128, activation='relu'))
Im_model.add(keras.layers.core.Dropout(0.5))
Im_model.add(keras.layers.Dense(units=64, activation='relu'))
Im_model.add(keras.layers.core.Dropout(0.5))
Im_model.add(keras.layers.Dense(units=128, activation='relu'))
Im_model.add(keras.layers.core.Dropout(0.5))
Im_model.add(keras.layers.Dense(units=64, activation='relu'))
Im_model.add(keras.layers.core.Dropout(0.5))
#最後一層 = 輸出層 output layer
Im_model.add(keras.layers.Dense(units=3, activation='linear'))

Im_model.compile(loss='mse',
              optimizer='adam',
              metrics=['accuracy'])

Train_Data = Train_Data_Array.values[:]
Train_Label = Train_Label_Array.values[:]

Test_Data = Test_Data_Array.values[:]
Test_Label = Test_Label_Array.values[:]

# 使用model訓練
history = Im_model.fit(Train_Data, Train_Label, epochs=1000, batch_size=30)
print(history)

# 使用model測試
loss_and_metrics = Im_model.evaluate(Test_Data, Test_Label)
print(loss_and_metrics)
# Out:
# Epoch 1/1000
# 127/127 [==============================] - 3s 23ms/step - loss: 218090189977631360.0000 - accuracy: 0.0945
# Epoch 2/1000
# 127/127 [==============================] - 0s 357us/step - loss: 218084074823486464.0000 - accuracy: 0.2126
# Epoch 3/1000
# 127/127 [==============================] - 0s 492us/step - loss: 218072472933167584.0000 - accuracy: 0.2126
# Epoch 4/1000
# 127/127 [==============================] - 0s 358us/step - loss: 218061469125499296.0000 - accuracy: 0.4252
# Epoch 5/1000
# 127/127 [==============================] - 0s 574us/step - loss: 218041083418324576.0000 - accuracy: 0.4567
# Epoch 6/1000
# 127/127 [==============================] - 0s 429us/step - loss: 218018575371660768.0000 - accuracy: 0.4961
# Epoch 7/1000
# 127/127 [==============================] - 0s 506us/step - loss: 217985145967173280.0000 - accuracy: 0.5354
# Epoch 8/1000
# 127/127 [==============================] - 0s 401us/step - loss: 217847679755877376.0000 - accuracy: 0.6142
# ...

# %%
print("使用106年資料訓練模型 使用107年資料預測營收")
for hotel_numbeer_counter in range(len(prediction)):
    print(hotel_numbeer_counter + 1 )
    print(I_Am_Hotel_Data_Year107.loc[hotel_numbeer_counter,"旅館名稱"])
    print("預測房租收入:{} 預測餐飲收入:{} 預測總營業收入:{}".format(prediction[hotel_numbeer_counter][0],prediction[hotel_numbeer_counter][1],prediction[hotel_numbeer_counter][2]))
    print("實際房租收入:{} 實際餐飲收入:{} 實際總營業收入:{}".format(Test_Label[hotel_numbeer_counter][0],Test_Label[hotel_numbeer_counter][1],Test_Label[hotel_numbeer_counter][2]))
# Out:
# 使用106年資料訓練模型 使用107年資料預測營收
# 1
# 福容大飯店 淡水漁人碼頭
# 預測房租收入:135233472.0 預測餐飲收入:144751680.0 預測總營業收入:319713600.0
# 實際房租收入:137907946.0 實際餐飲收入:184257129.0 實際總營業收入:344381889.0
# 2
# 大板根渡假酒店
# 預測房租收入:127842552.0 預測餐飲收入:136840544.0 預測總營業收入:302240192.0
# 實際房租收入:132578442.0 實際餐飲收入:151968702.0 實際總營業收入:449259697.0
# 3
# 板橋凱撒大飯店
# 預測房租收入:256627200.0 預測餐飲收入:274689792.0 預測總營業收入:606707968.0
# 實際房租收入:248653098.0 實際餐飲收入:369875334.0 實際總營業收入:642775070.0
# 4
# 圓山大飯店
# 預測房租收入:501616768.0 預測餐飲收入:536923008.0 預測總營業收入:1185902976.0
# 實際房租收入:511044025.0 實際餐飲收入:670364840.0 實際總營業收入:1330465249.0
# 5
# 國賓大飯店
# 預測房租收入:456896800.0 預測餐飲收入:489055456.0 預測總營業收入:1080177920.0
# 實際房租收入:431869398.0 實際餐飲收入:975370334.0 實際總營業收入:1503908852.0
# 6
# 台北華國大飯店
# 預測房租收入:335118720.0 預測餐飲收入:358706048.0 預測總營業收入:792274688.0
# 實際房租收入:265592096.0 實際餐飲收入:129097093.0 實際總營業收入:463257548.0
# 7
# 華泰王子大飯店
# 預測房租收入:232673472.0 預測餐飲收入:249050144.0 預測總營業收入:550077568.0
# 實際房租收入:171432645.0 實際餐飲收入:126950742.0 實際總營業收入:329582896.0
# 8
# 國王大飯店
# ...

# %%
#Classification Minst

# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

batch_size = 128
num_classes = 10
epochs = 2

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)


print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Using TensorFlow backend.
# ...
# 11493376/11490434 [==============================] - 6s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/2
# 60000/60000 [==============================] - 587s 10ms/step - loss: 0.2521 - accuracy: 0.9226 - val_loss: 0.0562 - val_accuracy: 0.9819
# Epoch 2/2
# 23552/60000 [==========>...................] - ETA: 5:32 - loss: 0.0920 - accuracy: 0.9717

# %%
#print(x_train)
#print(y_train)
#print(x_test)
#print(y_test)

print(model.predict(x_test[-10:]))
print(y_test[-10:])
